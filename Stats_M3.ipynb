# %% [markdown]
# #Theory Questions

# %% [markdown]
# ---
#
# ### 1. **What is hypothesis testing in statistics?**
#
# Hypothesis testing is a statistical method used to make decisions or inferences about population parameters based on sample data. It involves testing an assumption (hypothesis) by determining the probability that a sample statistic could have occurred by random chance.
#
# ---
#
# ### 2. **What is the null hypothesis, and how does it differ from the alternative hypothesis?**
#
# * **Null hypothesis (H₀):** Assumes there is no effect or difference (e.g., μ₁ = μ₂).
# * **Alternative hypothesis (H₁):** Assumes there is an effect or difference (e.g., μ₁ ≠ μ₂).
#   Hypothesis testing aims to determine whether there's enough evidence to reject the null hypothesis.
#
# ---
#
# ### 3. **What is the significance level in hypothesis testing, and why is it important?**
#
# The **significance level (α)** is the threshold for rejecting the null hypothesis, commonly set at 0.05. It represents the probability of making a Type I error (rejecting a true null hypothesis).
#
# ---
#
# ### 4. **What does a P-value represent in hypothesis testing?**
#
# A **P-value** is the probability of obtaining test results at least as extreme as the observed results, assuming the null hypothesis is true. A low P-value (typically < α) indicates strong evidence against the null hypothesis.
#
# ---
#
# ### 5. **How do you interpret the P-value in hypothesis testing?**
#
# * **P-value ≤ α:** Reject the null hypothesis; evidence supports the alternative hypothesis.
# * **P-value > α:** Fail to reject the null hypothesis; insufficient evidence to support the alternative.
#
# ---
#
# ### 6. **What are Type 1 and Type 2 errors in hypothesis testing?**
#
# * **Type I error:** Rejecting a true null hypothesis (false positive).
# * **Type II error:** Failing to reject a false null hypothesis (false negative).
#
# ---
#
# ### 7. **What is the difference between a one-tailed and a two-tailed test in hypothesis testing?**
#
# * **One-tailed test:** Tests for an effect in one direction (e.g., μ > μ₀).
# * **Two-tailed test:** Tests for an effect in both directions (e.g., μ ≠ μ₀).
#
# ---
#
# ### 8. **What is the Z-test, and when is it used in hypothesis testing?**
#
# A **Z-test** is used to test population means when the population standard deviation is known and the sample size is large (n ≥ 30). It assumes a normal distribution.
#
# ---
#
# ### 9. **How do you calculate the Z-score, and what does it represent in hypothesis testing?**
#
# **Z = (X̄ - μ) / (σ / √n)**
# It represents how many standard deviations a sample mean (X̄) is from the population mean (μ).
#
# ---
#
# ### 10. **What is the T-distribution, and when should it be used instead of the normal distribution?**
#
# The **T-distribution** is used when the sample size is small (n < 30) and the population standard deviation is unknown. It has heavier tails than the normal distribution.
#
# ---
#
# ### 11. **What is the difference between a Z-test and a T-test?**
#
# * **Z-test:** Known population standard deviation, large sample size.
# * **T-test:** Unknown population standard deviation, small sample size.
#
# ---
#
# ### 12. **What is the T-test, and how is it used in hypothesis testing?**
#
# A **T-test** evaluates whether the means of one or two groups are statistically different. It’s used for comparing means when standard deviation is unknown.
#
# ---
#
# ### 13. **What is the relationship between Z-test and T-test in hypothesis testing?**
#
# Both test means; Z-test is used for large samples with known variance, while T-test is used for small samples with unknown variance. As sample size increases, the T-distribution approaches the normal distribution.
#
# ---
#
# ### 14. **What is a confidence interval, and how is it used to interpret statistical results?**
#
# A **confidence interval (CI)** estimates a population parameter within a range, with a given confidence level (e.g., 95%). If a CI does not include the null value (e.g., 0 for difference in means), the result is statistically significant.
#
# ---
#
# ### 15. **What is the margin of error, and how does it affect the confidence interval?**
#
# The **margin of error** reflects the range of uncertainty around a sample estimate. A larger margin of error results in a wider confidence interval, indicating less precision.
#
# ---
#
# ### 16. **How is Bayes' Theorem used in statistics, and what is its significance?**
#
# **Bayes' Theorem** updates the probability of a hypothesis based on new evidence. It’s widely used in medical diagnostics, machine learning, and decision-making.
#
# ---
#
# ### 17. **What is the Chi-square distribution, and when is it used?**
#
# The **Chi-square distribution** is used in tests of independence and goodness of fit, particularly for categorical data.
#
# ---
#
# ### 18. **What is the Chi-square goodness of fit test, and how is it applied?**
#
# This test compares observed frequencies with expected frequencies to determine if a categorical variable fits a theoretical distribution.
#
# ---
#
# ### 19. **What is the F-distribution, and when is it used in hypothesis testing?**
#
# The **F-distribution** is used in ANOVA and tests comparing two variances. It is right-skewed and based on two degrees of freedom.
#
# ---
#
# ### 20. **What is an ANOVA test, and what are its assumptions?**
#
# **ANOVA (Analysis of Variance)** compares means across three or more groups.
# Assumptions:
#
# * Normality
# * Homogeneity of variance
# * Independence of observations
#
# ---
#
# ### 21. **What are the different types of ANOVA tests?**
#
# * **One-way ANOVA:** One independent variable.
# * **Two-way ANOVA:** Two independent variables.
# * **Repeated measures ANOVA:** Same subjects under different conditions.
#
# ---
#
# ### 22. **What is the F-test, and how does it relate to hypothesis testing?**
#
# An **F-test** compares two variances to determine if they are significantly different. It's the foundation of ANOVA and regression model comparisons.
#
# ---

# %% [markdown]
# #Practical Part 1

# %%
# 1. Write a Python program to generate a random variable and display its value.
import numpy as np

random_variable = np.random.rand()
print("Random Variable:", random_variable)
# Out:
# Random Variable: 0.6236118798978368

# %%
# 2. Generate a discrete uniform distribution using Python and plot the probability mass function (PMF).
import matplotlib.pyplot as plt
import numpy as np # Import numpy as it's used for np.arange and np.ones_like

values = np.arange(1, 7)  # Simulate a fair die roll
probabilities = np.ones_like(values) / len(values)

# Removed the 'use_line_collection=True' argument
plt.stem(values, probabilities)
plt.title("PMF of Discrete Uniform Distribution (1 to 6)")
plt.xlabel("Outcome")
plt.ylabel("Probability")
plt.grid(True)
plt.show()

# %%
# 3. Write a Python function to calculate the probability distribution function (PDF) of a Bernoulli distribution.
def bernoulli_pdf(p, x):
    if x not in [0, 1]:
        raise ValueError("x must be 0 or 1 for Bernoulli distribution.")
    return p**x * (1 - p)**(1 - x)

# Example usage:
print("P(X=1):", bernoulli_pdf(0.6, 1))
print("P(X=0):", bernoulli_pdf(0.6, 0))
# Out:
# P(X=1): 0.6
# P(X=0): 0.4

# %%
# 4. Write a Python script to simulate a binomial distribution with n=10 and p=0.5, then plot its histogram.
n, p = 10, 0.5
samples = np.random.binomial(n, p, 1000)

plt.hist(samples, bins=np.arange(n + 2) - 0.5, edgecolor='black')
plt.title("Binomial Distribution (n=10, p=0.5)")
plt.xlabel("Number of Successes")
plt.ylabel("Frequency")
plt.grid(True)
plt.show()

# %%
# 5. Create a Poisson distribution and visualize it using Python.
lambda_val = 4
samples = np.random.poisson(lambda_val, 1000)

plt.hist(samples, bins=range(0, max(samples)+2), edgecolor='black', align='left')
plt.title("Poisson Distribution (λ=4)")
plt.xlabel("Occurrences")
plt.ylabel("Frequency")
plt.grid(True)
plt.show()

# %%
# 6. Write a Python program to calculate and plot the cumulative distribution function (CDF) of a discrete uniform distribution.
values = np.arange(1, 7)
pmf = np.ones_like(values) / len(values)
cdf = np.cumsum(pmf)

plt.step(values, cdf, where='mid')
plt.title("CDF of Discrete Uniform Distribution (1 to 6)")
plt.xlabel("Value")
plt.ylabel("Cumulative Probability")
plt.grid(True)
plt.show()

# %%
# 7. Generate a continuous uniform distribution using NumPy and visualize it.
samples = np.random.uniform(low=0, high=1, size=1000)

plt.hist(samples, bins=20, edgecolor='black', density=True)
plt.title("Continuous Uniform Distribution (0 to 1)")
plt.xlabel("Value")
plt.ylabel("Density")
plt.grid(True)
plt.show()

# %%
# 8. Simulate data from a normal distribution and plot its histogram.
samples = np.random.normal(loc=0, scale=1, size=1000)

plt.hist(samples, bins=30, edgecolor='black', density=True)
plt.title("Normal Distribution (μ=0, σ=1)")
plt.xlabel("Value")
plt.ylabel("Density")
plt.grid(True)
plt.show()

# %%
# 9. Write a Python function to calculate Z-scores from a dataset and plot them.
def calculate_z_scores(data):
    mean = np.mean(data)
    std = np.std(data)
    return (data - mean) / std

data = np.random.normal(100, 15, size=100)
z_scores = calculate_z_scores(data)

plt.hist(z_scores, bins=30, edgecolor='black')
plt.title("Z-scores from Dataset")
plt.xlabel("Z-score")
plt.ylabel("Frequency")
plt.grid(True)
plt.show()

# %%
# 10. Implement the Central Limit Theorem (CLT) using Python for a non-normal distribution.
original_data = np.random.exponential(scale=2.0, size=10000)

sample_means = []
for _ in range(1000):
    sample = np.random.choice(original_data, size=30)
    sample_means.append(np.mean(sample))

plt.hist(sample_means, bins=30, edgecolor='black', density=True)
plt.title("Central Limit Theorem on Exponential Distribution")
plt.xlabel("Sample Mean")
plt.ylabel("Density")
plt.grid(True)
plt.show()

# %%
# 11. Simulate multiple samples from a normal distribution and verify the Central Limit Theorem.
sample_means = []

for _ in range(1000):
    sample = np.random.normal(loc=0, scale=1, size=30)
    sample_means.append(np.mean(sample))

plt.hist(sample_means, bins=30, edgecolor='black', density=True)
plt.title("Central Limit Theorem (Normal Distribution)")
plt.xlabel("Sample Mean")
plt.ylabel("Density")
plt.grid(True)
plt.show()

# %%
# 12. Write a Python function to calculate and plot the standard normal distribution (mean = 0, std = 1).
import scipy.stats as stats

x = np.linspace(-4, 4, 1000)
pdf = stats.norm.pdf(x, loc=0, scale=1)

plt.plot(x, pdf)
plt.title("Standard Normal Distribution (μ=0, σ=1)")
plt.xlabel("Z")
plt.ylabel("Probability Density")
plt.grid(True)
plt.show()

# %%
# 13. Generate random variables and calculate their corresponding probabilities using the binomial distribution.
import scipy.stats as stats
import matplotlib.pyplot as plt # Import matplotlib

n, p = 10, 0.5
x = np.arange(0, n+1)
pmf = stats.binom.pmf(x, n, p)

# Removed the 'use_line_collection=True' argument
plt.stem(x, pmf)
plt.title("Binomial Distribution PMF (n=10, p=0.5)")
plt.xlabel("Number of Successes")
plt.ylabel("Probability")
plt.grid(True)
plt.show()

# %%
# 14. Write a Python program to calculate the Z-score for a given data point and compare it to a standard normal distribution.
def z_score(x, mean, std):
    return (x - mean) / std

data_point = 85
mean = 70
std = 10
z = z_score(data_point, mean, std)
print(f"Z-score of {data_point} is {z}")
# Out:
# Z-score of 85 is 1.5

# %%
# 15. Implement hypothesis testing using Z-statistics for a sample dataset.
sample = np.random.normal(loc=52, scale=10, size=50)
population_mean = 50
sample_mean = np.mean(sample)
sample_std = np.std(sample, ddof=1)
z_stat = (sample_mean - population_mean) / (sample_std / np.sqrt(len(sample)))

print(f"Z-statistic: {z_stat}")
# Out:
# Z-statistic: 0.8489801533727618

# %%
# 16. Create a confidence interval for a dataset using Python and interpret the result.
import scipy.stats as stats

confidence = 0.95
n = len(sample)
stderr = stats.sem(sample)
ci = stats.t.interval(confidence, df=n-1, loc=sample_mean, scale=stderr)
print("95% Confidence Interval:", ci)
# Out:
# 95% Confidence Interval: (np.float64(47.94509188834725), np.float64(55.06125585207441))

# %%
# 17. Generate data from a normal distribution, then calculate and interpret the confidence interval for its mean.
data = np.random.normal(loc=100, scale=15, size=100)
mean = np.mean(data)
stderr = stats.sem(data)
ci = stats.norm.interval(0.95, loc=mean, scale=stderr)
print("Confidence Interval for Mean:", ci)
# Out:
# Confidence Interval for Mean: (np.float64(97.76597287716591), np.float64(102.81326065347587))

# %%
# 18. Write a Python script to calculate and visualize the probability density function (PDF) of a normal distribution.
x = np.linspace(60, 140, 1000)
pdf = stats.norm.pdf(x, loc=100, scale=15)

plt.plot(x, pdf)
plt.title("PDF of Normal Distribution (μ=100, σ=15)")
plt.xlabel("x")
plt.ylabel("Density")
plt.grid(True)
plt.show()

# %%
# 19. Use Python to calculate and interpret the cumulative distribution function (CDF) of a Poisson distribution.
x = np.arange(0, 15)
cdf = stats.poisson.cdf(x, mu=5)

plt.step(x, cdf, where='mid')
plt.title("CDF of Poisson Distribution (λ=5)")
plt.xlabel("x")
plt.ylabel("Cumulative Probability")
plt.grid(True)
plt.show()

# %%
# 20. Simulate a random variable using a continuous uniform distribution and calculate its expected value.
data = np.random.uniform(0, 1, size=1000)
expected_value = np.mean(data)
print("Expected Value (Continuous Uniform [0,1]):", expected_value)
# Out:
# Expected Value (Continuous Uniform [0,1]): 0.5051484594697713

# %%
# 21. Write a Python program to compare the standard deviations of two datasets and visualize the difference.
data1 = np.random.normal(50, 10, 1000)
data2 = np.random.normal(50, 20, 1000)

std1 = np.std(data1)
std2 = np.std(data2)

print("Standard Deviation of Dataset 1:", std1)
print("Standard Deviation of Dataset 2:", std2)

plt.hist(data1, bins=30, alpha=0.6, label='std=10')
plt.hist(data2, bins=30, alpha=0.6, label='std=20')
plt.title("Comparison of Two Normal Distributions")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Standard Deviation of Dataset 1: 10.05349895749627
# Standard Deviation of Dataset 2: 19.964771226005947

# %%
# 22. Calculate the range and interquartile range (IQR) of a dataset generated from a normal distribution.
data = np.random.normal(100, 20, 1000)
data_range = np.max(data) - np.min(data)
q1 = np.percentile(data, 25)
q3 = np.percentile(data, 75)
iqr = q3 - q1

print("Range:", data_range)
print("Interquartile Range (IQR):", iqr)
# Out:
# Range: 141.12524507205285
# Interquartile Range (IQR): 28.16670539236297

# %%
# 23. Implement Z-score normalization on a dataset and visualize its transformation.
data = np.random.normal(50, 15, 1000)
z_scores = (data - np.mean(data)) / np.std(data)

plt.hist(z_scores, bins=30, edgecolor='black')
plt.title("Z-score Normalized Data")
plt.xlabel("Z-score")
plt.ylabel("Frequency")
plt.grid(True)
plt.show()

# %%
# 24. Write a Python function to calculate the skewness and kurtosis of a dataset generated from a normal distribution.
from scipy.stats import skew, kurtosis

data = np.random.normal(0, 1, 1000)
print("Skewness:", skew(data))
print("Kurtosis:", kurtosis(data))
# Out:
# Skewness: 0.038634924450330906
# Kurtosis: -0.30483077379735146

# %% [markdown]
# #Practical Part - 2

# %%
# 1. Write a Python program to perform a Z-test for comparing a sample mean to a known population mean and interpret the results.
import scipy.stats as stats
import numpy as np

data = np.random.normal(loc=52, scale=10, size=50)
population_mean = 50
sample_mean = np.mean(data)
sample_std = np.std(data, ddof=1)
z_score = (sample_mean - population_mean) / (sample_std / np.sqrt(len(data)))
p_value = 2 * (1 - stats.norm.cdf(abs(z_score)))

print(f"Z-score: {z_score}, P-value: {p_value}")
# Out:
# Z-score: 0.707146392878635, P-value: 0.4794755080987134

# %%
# 2. Simulate random data to perform hypothesis testing and calculate the corresponding P-value using Python.
sample = np.random.normal(loc=55, scale=8, size=40)
t_stat, p_val = stats.ttest_1samp(sample, popmean=50)
print("T-statistic:", t_stat, "P-value:", p_val)
# Out:
# T-statistic: 2.5064669865626756 P-value: 0.016473363014905457

# %%
# 3. Implement a one-sample Z-test using Python to compare the sample mean with the population mean.
def one_sample_z_test(data, pop_mean):
    sample_mean = np.mean(data)
    sample_std = np.std(data, ddof=1)
    z = (sample_mean - pop_mean) / (sample_std / np.sqrt(len(data)))
    return z

z = one_sample_z_test(data, 50)
print("One-sample Z-test statistic:", z)
# Out:
# One-sample Z-test statistic: 0.707146392878635

# %%
# 4. Perform a two-tailed Z-test using Python and visualize the decision region on a plot.
x = np.linspace(-4, 4, 1000)
y = stats.norm.pdf(x)

plt.plot(x, y)
plt.axvline(-1.96, color='red', linestyle='--')
plt.axvline(1.96, color='red', linestyle='--')
plt.fill_between(x, y, where=(x <= -1.96) | (x >= 1.96), color='red', alpha=0.3)
plt.title("Two-tailed Z-test Decision Regions")
plt.grid(True)
plt.show()

# %%
# 5. Create a Python function that calculates and visualizes Type 1 and Type 2 errors during hypothesis testing.
def visualize_errors():
    x = np.linspace(-4, 4, 1000)
    null_dist = stats.norm.pdf(x, 0, 1)
    alt_dist = stats.norm.pdf(x, 1.5, 1)

    plt.plot(x, null_dist, label='Null Hypothesis')
    plt.plot(x, alt_dist, label='Alternative Hypothesis')
    plt.fill_between(x, null_dist, where=x > 1.96, color='red', alpha=0.3, label='Type I Error')
    plt.fill_between(x, alt_dist, where=x < 1.96, color='blue', alpha=0.3, label='Type II Error')
    plt.legend()
    plt.title("Type I and Type II Errors")
    plt.grid(True)
    plt.show()

visualize_errors()

# %%
# 6. Write a Python program to perform an independent T-test and interpret the results.
group1 = np.random.normal(100, 10, 30)
group2 = np.random.normal(102, 10, 30)

t_stat, p_value = stats.ttest_ind(group1, group2)
print("T-statistic:", t_stat, "P-value:", p_value)
# Out:
# T-statistic: -2.1286297373886507 P-value: 0.03754371897884454

# %%
# 7. Perform a paired sample T-test using Python and visualize the comparison results.
before = np.random.normal(100, 8, 30)
after = before + np.random.normal(2, 5, 30)

t_stat, p_val = stats.ttest_rel(before, after)
print("Paired T-test statistic:", t_stat, "P-value:", p_val)

plt.plot(before, label="Before")
plt.plot(after, label="After")
plt.legend()
plt.title("Paired Sample Data")
plt.grid(True)
plt.show()
# Out:
# Paired T-test statistic: -2.8748476750780068 P-value: 0.007495786778590937

# %%
# 8. Simulate data and perform both Z-test and T-test, then compare the results using Python.
sample_data = np.random.normal(50, 10, 35)

# Z-test
z_stat = (np.mean(sample_data) - 50) / (np.std(sample_data, ddof=1) / np.sqrt(len(sample_data)))
z_pval = 2 * (1 - stats.norm.cdf(abs(z_stat)))

# T-test
t_stat, t_pval = stats.ttest_1samp(sample_data, 50)

print(f"Z-test: Z = {z_stat}, P = {z_pval}")
print(f"T-test: T = {t_stat}, P = {t_pval}")
# Out:
# Z-test: Z = -1.9341561226621506, P = 0.053093935308276
# T-test: T = -1.9341561226621506, P = 0.06145205871813726

# %%
# 9. Write a Python function to calculate the confidence interval for a sample mean and explain its significance.
def confidence_interval(data, confidence=0.95):
    mean = np.mean(data)
    sem = stats.sem(data)
    interval = stats.t.interval(confidence, len(data)-1, loc=mean, scale=sem)
    return interval

ci = confidence_interval(data)
print("Confidence Interval (95%):", ci)
# Out:
# Confidence Interval (95%): (np.float64(47.94165932680616), np.float64(54.29346958451936))

# %%
# 10. Write a Python program to calculate the margin of error for a given confidence level using sample data.
def margin_of_error(data, confidence=0.95):
    sem = stats.sem(data)
    moe = sem * stats.t.ppf((1 + confidence) / 2., len(data)-1)
    return moe

moe = margin_of_error(data)
print("Margin of Error (95%):", moe)
# Out:
# Margin of Error (95%): 3.1759051288565963

# %%
# 11. Implement a Bayesian inference method using Bayes' Theorem in Python and explain the process.
# P(A|B) = P(B|A) * P(A) / P(B)
def bayes_theorem(p_a, p_b_given_a, p_b):
    return (p_b_given_a * p_a) / p_b

posterior = bayes_theorem(0.01, 0.9, 0.05)
print("Posterior Probability (Bayes' Theorem):", posterior)
# Out:
# Posterior Probability (Bayes' Theorem): 0.18000000000000002

# %%
# 12. Perform a Chi-square test for independence between two categorical variables in Python.
from scipy.stats import chi2_contingency

table = [[10, 20, 30],
         [20, 15, 25]]

chi2, p, dof, expected = chi2_contingency(table)
print("Chi-square Statistic:", chi2)
print("P-value:", p)
# Out:
# Chi-square Statistic: 4.502164502164502
# P-value: 0.10528521784009057

# %%
# 13. Write a Python program to calculate the expected frequencies for a Chi-square test based on observed data.
observed = np.array([[12, 18], [30, 40]])
chi2, p, dof, expected = chi2_contingency(observed)
print("Expected Frequencies:\n", expected)
# Out:
# Expected Frequencies:
#  [[12.6 17.4]
#  [29.4 40.6]]

# %%
# 14. Perform a goodness-of-fit test using Python to compare the observed data to an expected distribution.
observed = [18, 22, 20]
expected = [20, 20, 20]

chi2_stat, p_val = stats.chisquare(f_obs=observed, f_exp=expected)
print("Chi-square Goodness-of-Fit Statistic:", chi2_stat)
print("P-value:", p_val)
# Out:
# Chi-square Goodness-of-Fit Statistic: 0.4
# P-value: 0.8187307530779818
